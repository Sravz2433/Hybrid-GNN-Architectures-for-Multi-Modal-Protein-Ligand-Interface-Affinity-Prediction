# %%
# !pip install fair-esm
# !pip install rdkit
# !pip install biopython
# !pip install torch torchvision torchaudio --quiet
# !pip install torch_geometric --quiet
# !pip install scikit-learn matplotlib pandas --quiet
# Out:
# Collecting fair-esm
#   Downloading fair_esm-2.0.0-py3-none-any.whl.metadata (37 kB)
# Downloading fair_esm-2.0.0-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 4.2 MB/s eta 0:00:00
# Installing collected packages: fair-esm
# Successfully installed fair-esm-2.0.0
# Collecting rdkit
#   Downloading rdkit-2025.9.5-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rdkit) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from rdkit) (11.3.0)
# Downloading rdkit-2025.9.5-cp312-cp312-manylinux_2_28_x86_64.whl (36.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.7/36.7 MB 56.6 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: rdkit
# Successfully installed rdkit-2025.9.5
# Collecting biopython
#   Downloading biopython-1.86-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from biopython) (2.0.2)
# Downloading biopython-1.86-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 56.9 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: biopython
# Successfully installed biopython-1.86
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 30.6 MB/s eta 0:00:0000:01

# %%
import os
import numpy as np
import pandas as pd
import torch
from tqdm.auto import tqdm
import pickle

from Bio.PDB import PDBParser, PPBuilder
from rdkit import Chem
from rdkit.Chem import AllChem
from scipy.spatial.distance import cdist

from esm import pretrained
from torch_geometric.data import Data
import esm

# %%
AFF_CSV = "/kaggle/input/datasets/sravyasm/mailpdbdataset/pdbbind_v2020_refined_affinity.csv"
REFINED_DIR = "/kaggle/input/datasets/sravyasm/mailpdbdataset/PDBbind_v2020_refined/PDBbind_v2020_refined"
OUT_DIR = "/kaggle/working/processed"
GRAPH_DIR = os.path.join(OUT_DIR, "graphs")
skipped_ligands = []
skipped_empty_pocket = []


os.makedirs(GRAPH_DIR, exist_ok=True)
affinity_df = pd.read_csv(AFF_CSV)
print("Complexes:", len(affinity_df))
# Out:
# Complexes: 18690

# %%
from rdkit import Chem
import torch

def load_ligand(mol2_path):
    mol = None

    # Attempt 1: standard permissive load
    try:
        mol = Chem.MolFromMol2File(
            mol2_path,
            sanitize=False,
            removeHs=False
        )
    except Exception:
        mol = None

    # Attempt 2: raw block fallback
    if mol is None:
        try:
            with open(mol2_path, "r") as f:
                mol2_block = f.read()
            mol = Chem.MolFromMol2Block(
                mol2_block,
                sanitize=False,
                removeHs=False
            )
        except Exception:
            mol = None

    # Final fail → return None (do NOT raise)
    if mol is None or mol.GetNumAtoms() == 0:
        return None

    # Use crystal coordinates
    conf = mol.GetConformer()
    coords = conf.GetPositions()

    atom_feats = []
    for atom in mol.GetAtoms():
        atom_feats.append([
            atom.GetAtomicNum(),
            atom.GetFormalCharge(),
            int(atom.GetIsAromatic()),
            int(atom.GetHybridization())
        ])

    bonds = [(b.GetBeginAtomIdx(), b.GetEndAtomIdx()) for b in mol.GetBonds()]

    return (
        torch.tensor(atom_feats, dtype=torch.float),
        torch.tensor(coords, dtype=torch.float),
        bonds
    )

# %%
def load_protein_residues(pdb_path):
    parser = PDBParser(QUIET=True)
    structure = parser.get_structure("protein", pdb_path)

    residues = []
    coords = []

    for model in structure:
        for chain in model:
            for res in chain:
                if res.id[0] != " ":
                    continue
                if "CA" not in res:
                    continue
                residues.append(res)
                coords.append(res["CA"].get_coord())
        break

    return residues, torch.tensor(coords, dtype=torch.float)

# %%
def get_pocket_residues(lig_coords, prot_coords, cutoff=8.0):
    d = cdist(lig_coords.cpu(), prot_coords.cpu())
    mask = d.min(axis=0) <= cutoff
    idx = np.where(mask)[0]

    if len(idx) == 0:
        idx = np.argsort(d.min(axis=0))[:200]

    return idx

# %%
def extract_sequence(pdb_path):
    parser = PDBParser(QUIET=True)
    structure = parser.get_structure("protein", pdb_path)
    ppb = PPBuilder()

    seq = ""
    for pp in ppb.build_peptides(structure):
        seq += str(pp.get_sequence())
    return seq if seq else None
    
sequence_cache = {}
for _, row in tqdm(affinity_df.iterrows(), desc="Extracting sequences"):
    cid = row["complex_id"]
    pdb = os.path.join(REFINED_DIR, cid, f"{cid}_protein.pdb")
    if os.path.exists(pdb):
        seq = extract_sequence(pdb)
        if seq:
            sequence_cache[cid] = seq

with open(os.path.join(OUT_DIR, "protein_sequences.pkl"), "wb") as f:
    pickle.dump(sequence_cache, f)
# Out:
# Extracting sequences: 0it [00:00, ?it/s]

# %%
model, alphabet = esm.pretrained.esm2_t12_35M_UR50D()
model.eval().cuda()
batch_converter = alphabet.get_batch_converter()
MAX_LEN = 1024

seq = seq[:MAX_LEN]

batch = [("seq", seq)]
_, _, tokens = batch_converter(batch)
tokens = tokens.cuda()

with torch.no_grad():
    out = model(tokens, repr_layers=[12])

reps = out["representations"][12][0, 1:len(seq)+1].cpu()

del tokens, out
torch.cuda.empty_cache()

print(reps.shape)  # (seq_len, 480)


def batch_esm(seqs):
    embeddings = []

    for seq in seqs:
        if len(seq) > 1024:
            seq = seq[:1024]

        batch = [("seq", seq)]
        _, _, tokens = batch_converter(batch)
        tokens = tokens.cuda()

        with torch.no_grad():
            out = model(tokens, repr_layers=[12])

        rep = out["representations"][12][0, 1:len(seq)+1].cpu()
        embeddings.append(rep)

        del tokens, out
        torch.cuda.empty_cache()

    return embeddings

esm_cache = {}
cids = list(sequence_cache.keys())
seqs = [sequence_cache[c] for c in cids]
embs = batch_esm(seqs)

esm_cache = dict(zip(cids, embs))
# Out:
# Downloading: "https://dl.fbaipublicfiles.com/fair-esm/models/esm2_t12_35M_UR50D.pt" to /root/.cache/torch/hub/checkpoints/esm2_t12_35M_UR50D.pt
# Downloading: "https://dl.fbaipublicfiles.com/fair-esm/regression/esm2_t12_35M_UR50D-contact-regression.pt" to /root/.cache/torch/hub/checkpoints/esm2_t12_35M_UR50D-contact-regression.pt
# torch.Size([945, 480])

# %%
import torch
import numpy as np
from torch_geometric.data import Data
from scipy.spatial.distance import cdist

def build_graph(
    lig_x, lig_pos, lig_bonds,
    prot_residues, prot_pos, pocket_idx,
    esm_embedding, y,
    cutoff=8.0
):
    esm_dim = 480

    # --- Clip pocket indices safely ---
    max_esm_len = esm_embedding.size(0)
    pocket_idx = pocket_idx[pocket_idx < max_esm_len]
    if len(pocket_idx) == 0:
        return None

    # --- Center coordinates (optional but recommended) ---
    center = lig_pos.mean(dim=0)
    lig_pos = lig_pos - center
    prot_pos = prot_pos - center

    # --- Ligand node features ---
    lig_esm = torch.zeros(lig_x.size(0), esm_dim)
    lig_full = torch.cat([lig_x, lig_esm], dim=1)

    # --- Protein node features ---
    prot_struct = torch.zeros(len(pocket_idx), lig_x.size(1))
    prot_esm = esm_embedding[pocket_idx]
    prot_full = torch.cat([prot_struct, prot_esm], dim=1)

    # --- Combine nodes ---
    x = torch.cat([lig_full, prot_full], dim=0)

    # --- Add node-type encoding (0 = ligand, 1 = protein) ---
    L = lig_x.size(0)
    P = len(pocket_idx)

    node_type = torch.cat([
        torch.zeros(L, 1),
        torch.ones(P, 1)
    ], dim=0)

    x = torch.cat([x, node_type], dim=1)

    # --- Build edges ---
    src, dst = [], []

    # 1️⃣ Ligand–Ligand (bond edges)
    for i, j in lig_bonds:
        src += [i, j]
        dst += [j, i]

    # 2️⃣ Protein–Protein (distance-based)
    prot_coords = prot_pos[pocket_idx]
    d_pp = cdist(prot_coords, prot_coords)
    i_pp, j_pp = np.where((d_pp < cutoff) & (d_pp > 0))

    src += (i_pp + L).tolist()
    dst += (j_pp + L).tolist()

    # 3️⃣ Ligand–Protein interaction edges
    d_lp = cdist(lig_pos, prot_coords)
    i_lp, j_lp = np.where(d_lp < cutoff)

    src += i_lp.tolist()
    dst += (j_lp + L).tolist()

    src += (j_lp + L).tolist()
    dst += i_lp.tolist()

    # --- Final edge tensor ---
    edge_index = torch.tensor([src, dst], dtype=torch.long)

    # --- Combine positions ---
    pos = torch.cat([lig_pos, prot_coords], dim=0)

    return Data(
        x=x,
        edge_index=edge_index,
        pos=pos,
        y=torch.tensor([y], dtype=torch.float)
    )

# %%
for _, row in tqdm(affinity_df.iterrows(), desc="Building graphs"):
    cid = row["complex_id"]
    y = row["pK"]

    lig_path = os.path.join(REFINED_DIR, cid, f"{cid}_ligand.mol2")
    prot_path = os.path.join(REFINED_DIR, cid, f"{cid}_protein.pdb")

    if not (os.path.exists(lig_path) and os.path.exists(prot_path)):
        continue
    if cid not in esm_cache:
        continue

    lig_data = load_ligand(lig_path)
    if lig_data is None:
        skipped_ligands.append(cid)
        continue
    
    lig_x, lig_pos, lig_bonds = lig_data

    prot_res, prot_pos = load_protein_residues(prot_path)

    pocket_idx = get_pocket_residues(lig_pos, prot_pos)

    data = build_graph(
        lig_x, lig_pos, lig_bonds,
        prot_res, prot_pos,
        pocket_idx,
        esm_cache[cid],
        y
    )
    if data is None:
        skipped_empty_pocket.append(cid)
        continue
    torch.save(data, os.path.join(GRAPH_DIR, f"{cid}.pt"))
# Out:
# Building graphs: 0it [00:00, ?it/s]
# /tmp/ipykernel_55/1086695430.py:19: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:253.)
#   return residues, torch.tensor(coords, dtype=torch.float)
# [12:01:49] 1epq_ligand: warning - O.co2 with non C.2 or S.o2 neighbor.
# [12:01:49] 1epq_ligand: warning - O.co2 with non C.2 or S.o2 neighbor.
# [12:02:33] 1bq4_ligand: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# [12:05:15] 1nki_ligand: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# [12:06:23] 1t5a_ligand: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# [12:07:23] 2hwg_ligand: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# [12:07:30] 2dua_ligand: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# [12:08:39] 2o1c_ligand: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# [12:08:42] 2it4_ligand: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# [12:10:26] 2rk8_ligand: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# [12:10:38]
#
# ****
# Pre-condition Violation
# bond already exists
# Violation occurred on line 408 in file /project/build/temp.linux-x86_64-cpython-312/rdkit/Code/GraphMol/ROMol.cpp
# Failed Expression: !(boost::edge(bond_pin->getBeginAtomIdx(), bond_pin->getEndAtomIdx(), d_graph) .second)
# ----------
# Stacktrace:
# ----------
# ****
#
# [12:10:38]
#
# ****
# Pre-condition Violation
# bond already exists
# Violation occurred on line 408 in file /project/build/temp.linux-x86_64-cpython-312/rdkit/Code/GraphMol/ROMol.cpp
# Failed Expression: !(boost::edge(bond_pin->getBeginAtomIdx(), bond_pin->getEndAtomIdx(), d_graph) .second)
# ----------
# Stacktrace:
# ----------
# ****
#
# [12:10:38] 2rk7_ligand: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# [12:12:22] 3c14_ligand: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# [12:14:21] 3mof_ligand: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:46] 4d8n_ligand: warning - aromatic N with 3 aromatic bonds - skipping charge guess for this atom
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:06] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:17:24] 3tvl_ligand: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# [12:21:41] 4u5t_ligand: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# [12:21:41] 4u5t_ligand: warning - O.co2 with non C.2 or S.o2 neighbor.
# [12:21:41] 4u5t_ligand: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# [12:21:41] 4u5t_ligand: warning - O.co2 with non C.2 or S.o2 neighbor.
# [12:23:10] 4mg5_ligand: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# [12:27:02] 5jim_ligand: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# [12:27:11] 5jid_ligand: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# [12:33:42] 6gon_ligand: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# [12:33:42] 6goo_ligand: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# [12:35:28] 6mny_ligand: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# [12:37:55] 6pvu_ligand: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.

# %%
import os

GRAPH_DIR = "/kaggle/working/processed/graphs"

pt_files = [f for f in os.listdir(GRAPH_DIR) if f.endswith(".pt")]
print("Number of .pt files:", len(pt_files))
# Out:
# Number of .pt files: 18649

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import random
import matplotlib.pyplot as plt
from torch_geometric.nn import GCNConv, SAGEConv, GINConv, global_mean_pool
from torch_geometric.loader import DataLoader
import os
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.calibration import calibration_curve
from scipy.stats import spearmanr

# %%
import os
import torch
import numpy as np
import pickle
from torch_geometric.loader import DataLoader

# ============================
# 1️⃣ Load graphs and extract IDs
# ============================

graph_files = [f for f in os.listdir(GRAPH_DIR) if f.endswith(".pt")]

graphs = []
complex_ids = []

for f in graph_files:
    cid = f.replace(".pt", "")  # PDB ID
    data = torch.load(os.path.join(GRAPH_DIR, f), weights_only=False)
    graphs.append(data)
    complex_ids.append(cid)

print("Total graphs loaded:", len(graphs))


# ============================
# 2️⃣ Protein-Level Split
# ============================

SPLIT_SEED = 42
split_path = "/kaggle/working/protein_split.pkl"

if os.path.exists(split_path):
    print("Loading existing protein-level split...")
    with open(split_path, "rb") as f:
        split_dict = pickle.load(f)

    train_ids = split_dict["train_ids"]
    val_ids = split_dict["val_ids"]
    test_ids = split_dict["test_ids"]

else:
    print("Creating new protein-level split...")

    np.random.seed(SPLIT_SEED)

    unique_ids = np.array(complex_ids)
    np.random.shuffle(unique_ids)

    n = len(unique_ids)
    n_train = int(0.7 * n)
    n_val = int(0.15 * n)

    train_ids = unique_ids[:n_train]
    val_ids = unique_ids[n_train:n_train+n_val]
    test_ids = unique_ids[n_train+n_val:]

    split_dict = {
        "train_ids": train_ids,
        "val_ids": val_ids,
        "test_ids": test_ids
    }

    with open(split_path, "wb") as f:
        pickle.dump(split_dict, f)

print("Train proteins:", len(train_ids))
print("Val proteins:", len(val_ids))
print("Test proteins:", len(test_ids))


# ============================
# 3️⃣ Assign graphs to splits
# ============================

train_graphs = []
val_graphs = []
test_graphs = []

train_set = set(train_ids)
val_set = set(val_ids)
test_set = set(test_ids)

for graph, cid in zip(graphs, complex_ids):
    if cid in train_set:
        train_graphs.append(graph)
    elif cid in val_set:
        val_graphs.append(graph)
    elif cid in test_set:
        test_graphs.append(graph)

print("Train:", len(train_graphs))
print("Val:", len(val_graphs))
print("Test:", len(test_graphs))


# ============================
# 4️⃣ Create DataLoaders
# ============================

train_loader = DataLoader(train_graphs, batch_size=32, shuffle=True)
val_loader = DataLoader(val_graphs, batch_size=32)
test_loader = DataLoader(test_graphs, batch_size=32)

print("DataLoaders ready.")
# Out:
# Total graphs loaded: 18649
# Creating new protein-level split...
# Train proteins: 13054
# Val proteins: 2797
# Test proteins: 2798
# Train: 13054
# Val: 2797
# Test: 2798
# DataLoaders ready.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import SAGEConv, global_mean_pool

class SAGE3(nn.Module):
    def __init__(self, in_dim=4, hidden_dim=128, dropout=0.2):
        super(SAGE3, self).__init__()

        self.conv1 = SAGEConv(in_dim, hidden_dim, aggr="mean")
        self.conv2 = SAGEConv(hidden_dim, hidden_dim, aggr="mean")
        self.conv3 = SAGEConv(hidden_dim, hidden_dim, aggr="mean")

        self.bn1 = nn.BatchNorm1d(hidden_dim)
        self.bn2 = nn.BatchNorm1d(hidden_dim)
        self.bn3 = nn.BatchNorm1d(hidden_dim)

        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_dim, 1)

    def forward(self, x, edge_index, batch):

        x = self.conv1(x, edge_index)
        x = self.bn1(x)
        x = F.relu(x)
        x = self.dropout(x)

        x = self.conv2(x, edge_index)
        x = self.bn2(x)
        x = F.relu(x)
        x = self.dropout(x)

        x = self.conv3(x, edge_index)
        x = self.bn3(x)
        x = F.relu(x)
        x = self.dropout(x)

        x = global_mean_pool(x, batch)
        x = self.fc(x)

        return x.squeeze(-1)


def train_one_epoch(model, loader, optimizer, criterion, device):
    model.train()
    total_loss = 0
    for batch in loader:
        batch = batch.to(device)
        optimizer.zero_grad()
        out = model(batch.x, batch.edge_index, batch.batch)
        loss = criterion(out, batch.y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * batch.num_graphs
    return total_loss / len(loader.dataset)

def evaluate(model, loader, device):
    model.eval()
    preds = []
    trues = []
    with torch.no_grad():
        for batch in loader:
            batch = batch.to(device)
            out = model(batch.x, batch.edge_index, batch.batch)
            preds.append(out.cpu().numpy())
            trues.append(batch.y.cpu().numpy())
    preds = np.concatenate(preds)
    trues = np.concatenate(trues)
    mse = mean_squared_error(trues, preds)
    rmse = np.sqrt(mse)
    r2 = r2_score(trues, preds)
    return mse, rmse, r2, preds, trues

def mc_evaluate(model, loader, device, n_passes=30):
    model.train()  # Enable dropout for uncertainty
    all_mean_preds = []
    all_std_preds = []
    all_trues = []
    with torch.no_grad():
        for batch in loader:
            batch = batch.to(device)
            preds = []
            for _ in range(n_passes):
                out = model(batch.x, batch.edge_index, batch.batch)
                preds.append(out.cpu().numpy())
            preds = np.stack(preds)  # [n_passes, batch_size]
            mean_pred = preds.mean(axis=0)
            std_pred = preds.std(axis=0)
            all_mean_preds.append(mean_pred)
            all_std_preds.append(std_pred)
            all_trues.append(batch.y.cpu().numpy())
    all_mean_preds = np.concatenate(all_mean_preds)
    all_std_preds = np.concatenate(all_std_preds)
    all_trues = np.concatenate(all_trues)
    return all_mean_preds, all_std_preds, all_trues

def compute_ece(preds, trues, n_bins=10):
    bin_bounds = np.linspace(min(preds), max(preds), n_bins + 1)
    bin_indices = np.digitize(preds, bin_bounds) - 1
    ece = 0.0
    for i in range(n_bins):
        in_bin = bin_indices == i
        if np.any(in_bin):
            bin_preds = preds[in_bin]
            bin_trues = trues[in_bin]
            bin_error = mean_absolute_error(bin_trues, bin_preds)
            bin_weight = len(bin_trues) / len(trues)
            ece += bin_weight * bin_error
    return ece

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
example_in_dim = graphs[0].x.shape[1]

EPOCHS = 50
seeds = [0, 1, 2, 3, 4]
seed_rmses = []
seed_r2s = []
seed_corrs = []
seed_eces = []

for seed in seeds:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)

    model = SAGE3(
        in_dim=example_in_dim,
        hidden_dim=256,
        dropout=0.1
    ).to(device)
    optimizer = torch.optim.Adam(
        model.parameters(),
        lr=1e-3,
        weight_decay=1e-5
    )
    criterion = nn.MSELoss()

    best_val_rmse = float("inf")
    for epoch in range(1, EPOCHS + 1):
        train_loss = train_one_epoch(
            model, train_loader, optimizer, criterion, device
        )
        val_mse, val_rmse, val_r2, _, _ = evaluate(
            model, val_loader, device
        )
        print(
            f"Seed {seed} | Epoch {epoch:03d} | "
            f"Train Loss: {train_loss:.4f} | "
            f"Val RMSE: {val_rmse:.4f} | "
            f"R2: {val_r2:.4f}"
        )
        if val_rmse < best_val_rmse:
            best_val_rmse = val_rmse
            torch.save(model.state_dict(), f"gcn_sage_gin_best_seed{seed}.pt")
            print(f"✓ Saved best model for seed {seed} (Val RMSE={val_rmse:.4f})")

    model.load_state_dict(torch.load(f"gcn_sage_gin_best_seed{seed}.pt"))
    test_mse, test_rmse, test_r2, det_preds, det_trues = evaluate(model, test_loader, device)
    seed_rmses.append(test_rmse)
    seed_r2s.append(test_r2)

    # MC for uncertainty corr
    mean_preds, std_preds, trues = mc_evaluate(model, test_loader, device)
    abs_errors = np.abs(mean_preds - trues)
    corr, _ = spearmanr(std_preds, abs_errors)
    seed_corrs.append(corr)

    # ECE on deterministic preds
    ece = compute_ece(det_preds, det_trues)
    seed_eces.append(ece)

    print(f"Seed {seed} TEST: RMSE={test_rmse:.4f}, R2={test_r2:.4f}, Unc-Err Corr={corr:.4f}, ECE={ece:.4f}")

print("\nAGGREGATE RESULTS (5 seeds):")
print(f"RMSE mean: {np.mean(seed_rmses):.4f}, range: {min(seed_rmses):.4f}-{max(seed_rmses):.4f}")
print(f"R2 mean: {np.mean(seed_r2s):.4f}, range: {min(seed_r2s):.4f}-{max(seed_r2s):.4f}")
print(f"Unc-Err Corr mean: {np.mean(seed_corrs):.4f}")
print(f"ECE mean: {np.mean(seed_eces):.4f}")
# Out:
# Using device: cuda
# Seed 0 | Epoch 001 | Train Loss: 4.4493 | Val RMSE: 1.6663 | R2: 0.1443
# ✓ Saved best model for seed 0 (Val RMSE=1.6663)
# Seed 0 | Epoch 002 | Train Loss: 2.2377 | Val RMSE: 1.6135 | R2: 0.1977
# ✓ Saved best model for seed 0 (Val RMSE=1.6135)
# Seed 0 | Epoch 003 | Train Loss: 2.0885 | Val RMSE: 1.4909 | R2: 0.3150
# ✓ Saved best model for seed 0 (Val RMSE=1.4909)
# Seed 0 | Epoch 004 | Train Loss: 1.9905 | Val RMSE: 1.4705 | R2: 0.3336
# ✓ Saved best model for seed 0 (Val RMSE=1.4705)
# Seed 0 | Epoch 005 | Train Loss: 1.8867 | Val RMSE: 1.4539 | R2: 0.3485
# ✓ Saved best model for seed 0 (Val RMSE=1.4539)
# Seed 0 | Epoch 006 | Train Loss: 1.7903 | Val RMSE: 1.4460 | R2: 0.3556
# ✓ Saved best model for seed 0 (Val RMSE=1.4460)
# Seed 0 | Epoch 007 | Train Loss: 1.7060 | Val RMSE: 1.4171 | R2: 0.3811
# ✓ Saved best model for seed 0 (Val RMSE=1.4171)
# Seed 0 | Epoch 008 | Train Loss: 1.6386 | Val RMSE: 1.4097 | R2: 0.3876
# ✓ Saved best model for seed 0 (Val RMSE=1.4097)
# Seed 0 | Epoch 009 | Train Loss: 1.5745 | Val RMSE: 1.3722 | R2: 0.4198
# ✓ Saved best model for seed 0 (Val RMSE=1.3722)
# Seed 0 | Epoch 010 | Train Loss: 1.5238 | Val RMSE: 1.3858 | R2: 0.4082
# Seed 0 | Epoch 011 | Train Loss: 1.4452 | Val RMSE: 1.4119 | R2: 0.3857
# Seed 0 | Epoch 012 | Train Loss: 1.4013 | Val RMSE: 1.3842 | R2: 0.4096
# Seed 0 | Epoch 013 | Train Loss: 1.3656 | Val RMSE: 1.3463 | R2: 0.4414
# ✓ Saved best model for seed 0 (Val RMSE=1.3463)
# Seed 0 | Epoch 014 | Train Loss: 1.3126 | Val RMSE: 1.4342 | R2: 0.3661
# Seed 0 | Epoch 015 | Train Loss: 1.2773 | Val RMSE: 1.3473 | R2: 0.4406
# Seed 0 | Epoch 016 | Train Loss: 1.2173 | Val RMSE: 1.3529 | R2: 0.4360
# Seed 0 | Epoch 017 | Train Loss: 1.1851 | Val RMSE: 1.4084 | R2: 0.3887
# Seed 0 | Epoch 018 | Train Loss: 1.1392 | Val RMSE: 1.3482 | R2: 0.4399
# Seed 0 | Epoch 019 | Train Loss: 1.1060 | Val RMSE: 1.3769 | R2: 0.4158
# Seed 0 | Epoch 020 | Train Loss: 1.0724 | Val RMSE: 1.3385 | R2: 0.4479
# ✓ Saved best model for seed 0 (Val RMSE=1.3385)
# Seed 0 | Epoch 021 | Train Loss: 1.0413 | Val RMSE: 1.3555 | R2: 0.4338
# Seed 0 | Epoch 022 | Train Loss: 1.0009 | Val RMSE: 1.3555 | R2: 0.4338
# Seed 0 | Epoch 023 | Train Loss: 0.9959 | Val RMSE: 1.3151 | R2: 0.4670
# ✓ Saved best model for seed 0 (Val RMSE=1.3151)
# Seed 0 | Epoch 024 | Train Loss: 0.9695 | Val RMSE: 1.3414 | R2: 0.4455
# Seed 0 | Epoch 025 | Train Loss: 0.9283 | Val RMSE: 1.3459 | R2: 0.4417
# Seed 0 | Epoch 026 | Train Loss: 0.9218 | Val RMSE: 1.3585 | R2: 0.4313
# Seed 0 | Epoch 027 | Train Loss: 0.8867 | Val RMSE: 1.3372 | R2: 0.4489
# Seed 0 | Epoch 028 | Train Loss: 0.8522 | Val RMSE: 1.3306 | R2: 0.4544
# Seed 0 | Epoch 029 | Train Loss: 0.8428 | Val RMSE: 1.3344 | R2: 0.4513
# Seed 0 | Epoch 030 | Train Loss: 0.8256 | Val RMSE: 1.3403 | R2: 0.4464
# Seed 0 | Epoch 031 | Train Loss: 0.8144 | Val RMSE: 1.3329 | R2: 0.4525
# Seed 0 | Epoch 032 | Train Loss: 0.8023 | Val RMSE: 1.3513 | R2: 0.4373
# Seed 0 | Epoch 033 | Train Loss: 0.7740 | Val RMSE: 1.3168 | R2: 0.4656
# Seed 0 | Epoch 034 | Train Loss: 0.7498 | Val RMSE: 1.3290 | R2: 0.4557
# Seed 0 | Epoch 035 | Train Loss: 0.7479 | Val RMSE: 1.3411 | R2: 0.4458
# Seed 0 | Epoch 036 | Train Loss: 0.7273 | Val RMSE: 1.3655 | R2: 0.4254
# Seed 0 | Epoch 037 | Train Loss: 0.7064 | Val RMSE: 1.3593 | R2: 0.4306
# Seed 0 | Epoch 038 | Train Loss: 0.7099 | Val RMSE: 1.3403 | R2: 0.4464
# Seed 0 | Epoch 039 | Train Loss: 0.6853 | Val RMSE: 1.3100 | R2: 0.4712
# ✓ Saved best model for seed 0 (Val RMSE=1.3100)
# Seed 0 | Epoch 040 | Train Loss: 0.6648 | Val RMSE: 1.3509 | R2: 0.4377
# Seed 0 | Epoch 041 | Train Loss: 0.6689 | Val RMSE: 1.3410 | R2: 0.4458
# Seed 0 | Epoch 042 | Train Loss: 0.6438 | Val RMSE: 1.3165 | R2: 0.4659
# Seed 0 | Epoch 043 | Train Loss: 0.6349 | Val RMSE: 1.3366 | R2: 0.4494
# Seed 0 | Epoch 044 | Train Loss: 0.6207 | Val RMSE: 1.4010 | R2: 0.3951
# Seed 0 | Epoch 045 | Train Loss: 0.6320 | Val RMSE: 1.3233 | R2: 0.4604
# Seed 0 | Epoch 046 | Train Loss: 0.6083 | Val RMSE: 1.3913 | R2: 0.4035
# Seed 0 | Epoch 047 | Train Loss: 0.5907 | Val RMSE: 1.4102 | R2: 0.3872
# Seed 0 | Epoch 048 | Train Loss: 0.5921 | Val RMSE: 1.3511 | R2: 0.4375
# Seed 0 | Epoch 049 | Train Loss: 0.5758 | Val RMSE: 1.3197 | R2: 0.4633
# Seed 0 | Epoch 050 | Train Loss: 0.5876 | Val RMSE: 1.3382 | R2: 0.4482
# Seed 0 TEST: RMSE=1.2779, R2=0.4742, Unc-Err Corr=-0.0006, ECE=0.9748
# Seed 1 | Epoch 001 | Train Loss: 4.1088 | Val RMSE: 1.5752 | R2: 0.2354
# ✓ Saved best model for seed 1 (Val RMSE=1.5752)
# Seed 1 | Epoch 002 | Train Loss: 2.2202 | Val RMSE: 1.5012 | R2: 0.3055
# ✓ Saved best model for seed 1 (Val RMSE=1.5012)
# Seed 1 | Epoch 003 | Train Loss: 2.0806 | Val RMSE: 1.5115 | R2: 0.2960
# Seed 1 | Epoch 004 | Train Loss: 1.9812 | Val RMSE: 1.4866 | R2: 0.3189
# ✓ Saved best model for seed 1 (Val RMSE=1.4866)
# Seed 1 | Epoch 005 | Train Loss: 1.8888 | Val RMSE: 1.4681 | R2: 0.3358
# ✓ Saved best model for seed 1 (Val RMSE=1.4681)
# Seed 1 | Epoch 006 | Train Loss: 1.7900 | Val RMSE: 1.4301 | R2: 0.3697
# ✓ Saved best model for seed 1 (Val RMSE=1.4301)
# Seed 1 | Epoch 007 | Train Loss: 1.7383 | Val RMSE: 1.4879 | R2: 0.3177
# Seed 1 | Epoch 008 | Train Loss: 1.6450 | Val RMSE: 1.4072 | R2: 0.3898
# ✓ Saved best model for seed 1 (Val RMSE=1.4072)
# Seed 1 | Epoch 009 | Train Loss: 1.5871 | Val RMSE: 1.3909 | R2: 0.4038
# ✓ Saved best model for seed 1 (Val RMSE=1.3909)
# Seed 1 | Epoch 010 | Train Loss: 1.5234 | Val RMSE: 1.5130 | R2: 0.2946
# Seed 1 | Epoch 011 | Train Loss: 1.4629 | Val RMSE: 1.4152 | R2: 0.3828
# Seed 1 | Epoch 012 | Train Loss: 1.4360 | Val RMSE: 1.3384 | R2: 0.4480
# ✓ Saved best model for seed 1 (Val RMSE=1.3384)
# Seed 1 | Epoch 013 | Train Loss: 1.3847 | Val RMSE: 1.3758 | R2: 0.4167
# Seed 1 | Epoch 014 | Train Loss: 1.3357 | Val RMSE: 1.3992 | R2: 0.3967
# Seed 1 | Epoch 015 | Train Loss: 1.2878 | Val RMSE: 1.3665 | R2: 0.4246
# Seed 1 | Epoch 016 | Train Loss: 1.2472 | Val RMSE: 1.3429 | R2: 0.4442
# Seed 1 | Epoch 017 | Train Loss: 1.2091 | Val RMSE: 1.3325 | R2: 0.4528
# ✓ Saved best model for seed 1 (Val RMSE=1.3325)
# Seed 1 | Epoch 018 | Train Loss: 1.1637 | Val RMSE: 1.3779 | R2: 0.4149
# Seed 1 | Epoch 019 | Train Loss: 1.1588 | Val RMSE: 1.3241 | R2: 0.4597
# ✓ Saved best model for seed 1 (Val RMSE=1.3241)
# Seed 1 | Epoch 020 | Train Loss: 1.0941 | Val RMSE: 1.3816 | R2: 0.4118
# Seed 1 | Epoch 021 | Train Loss: 1.0778 | Val RMSE: 1.3687 | R2: 0.4227
# Seed 1 | Epoch 022 | Train Loss: 1.0458 | Val RMSE: 1.3249 | R2: 0.4591
# Seed 1 | Epoch 023 | Train Loss: 1.0320 | Val RMSE: 1.3243 | R2: 0.4595
# Seed 1 | Epoch 024 | Train Loss: 1.0030 | Val RMSE: 1.3391 | R2: 0.4474
# Seed 1 | Epoch 025 | Train Loss: 0.9893 | Val RMSE: 1.3142 | R2: 0.4678
# ✓ Saved best model for seed 1 (Val RMSE=1.3142)
# Seed 1 | Epoch 026 | Train Loss: 0.9451 | Val RMSE: 1.3793 | R2: 0.4137
# Seed 1 | Epoch 027 | Train Loss: 0.9224 | Val RMSE: 1.3517 | R2: 0.4370
# Seed 1 | Epoch 028 | Train Loss: 0.9034 | Val RMSE: 1.3324 | R2: 0.4529
# Seed 1 | Epoch 029 | Train Loss: 0.9103 | Val RMSE: 1.3070 | R2: 0.4736
# ✓ Saved best model for seed 1 (Val RMSE=1.3070)
# Seed 1 | Epoch 030 | Train Loss: 0.8640 | Val RMSE: 1.2988 | R2: 0.4801
# ✓ Saved best model for seed 1 (Val RMSE=1.2988)
# Seed 1 | Epoch 031 | Train Loss: 0.8399 | Val RMSE: 1.3629 | R2: 0.4276
# Seed 1 | Epoch 032 | Train Loss: 0.8486 | Val RMSE: 1.2926 | R2: 0.4851
# ✓ Saved best model for seed 1 (Val RMSE=1.2926)
# Seed 1 | Epoch 033 | Train Loss: 0.8106 | Val RMSE: 1.3522 | R2: 0.4365
# Seed 1 | Epoch 034 | Train Loss: 0.7981 | Val RMSE: 1.5110 | R2: 0.2964
# Seed 1 | Epoch 035 | Train Loss: 0.7760 | Val RMSE: 1.3310 | R2: 0.4541
# Seed 1 | Epoch 036 | Train Loss: 0.7678 | Val RMSE: 1.3142 | R2: 0.4678
# Seed 1 | Epoch 037 | Train Loss: 0.7542 | Val RMSE: 1.3405 | R2: 0.4463
# Seed 1 | Epoch 038 | Train Loss: 0.7348 | Val RMSE: 1.3150 | R2: 0.4671
# Seed 1 | Epoch 039 | Train Loss: 0.7165 | Val RMSE: 1.3183 | R2: 0.4645
# Seed 1 | Epoch 040 | Train Loss: 0.7181 | Val RMSE: 1.3896 | R2: 0.4049
# Seed 1 | Epoch 041 | Train Loss: 0.7016 | Val RMSE: 1.4257 | R2: 0.3736
# Seed 1 | Epoch 042 | Train Loss: 0.6821 | Val RMSE: 1.3408 | R2: 0.4460
# Seed 1 | Epoch 043 | Train Loss: 0.6617 | Val RMSE: 1.3292 | R2: 0.4555
# Seed 1 | Epoch 044 | Train Loss: 0.6547 | Val RMSE: 1.3111 | R2: 0.4703
# Seed 1 | Epoch 045 | Train Loss: 0.6552 | Val RMSE: 1.3237 | R2: 0.4601
# Seed 1 | Epoch 046 | Train Loss: 0.6512 | Val RMSE: 1.3121 | R2: 0.4694
# Seed 1 | Epoch 047 | Train Loss: 0.6260 | Val RMSE: 1.3567 | R2: 0.4328
# Seed 1 | Epoch 048 | Train Loss: 0.6232 | Val RMSE: 1.3162 | R2: 0.4661
# Seed 1 | Epoch 049 | Train Loss: 0.6167 | Val RMSE: 1.3089 | R2: 0.4721
# Seed 1 | Epoch 050 | Train Loss: 0.5799 | Val RMSE: 1.3670 | R2: 0.4241
# Seed 1 TEST: RMSE=1.2742, R2=0.4773, Unc-Err Corr=0.0442, ECE=0.9785
# Seed 2 | Epoch 001 | Train Loss: 4.5689 | Val RMSE: 1.5782 | R2: 0.2325
# ✓ Saved best model for seed 2 (Val RMSE=1.5782)
# Seed 2 | Epoch 002 | Train Loss: 2.2420 | Val RMSE: 1.5323 | R2: 0.2765
# ✓ Saved best model for seed 2 (Val RMSE=1.5323)
# Seed 2 | Epoch 003 | Train Loss: 2.0830 | Val RMSE: 1.4969 | R2: 0.3095
# ✓ Saved best model for seed 2 (Val RMSE=1.4969)
# Seed 2 | Epoch 004 | Train Loss: 1.9797 | Val RMSE: 1.4517 | R2: 0.3505
# ✓ Saved best model for seed 2 (Val RMSE=1.4517)
# Seed 2 | Epoch 005 | Train Loss: 1.8627 | Val RMSE: 1.4629 | R2: 0.3405
# Seed 2 | Epoch 006 | Train Loss: 1.8020 | Val RMSE: 1.4247 | R2: 0.3745
# ✓ Saved best model for seed 2 (Val RMSE=1.4247)
# Seed 2 | Epoch 007 | Train Loss: 1.7274 | Val RMSE: 1.4341 | R2: 0.3662
# Seed 2 | Epoch 008 | Train Loss: 1.6606 | Val RMSE: 1.4706 | R2: 0.3335
# Seed 2 | Epoch 009 | Train Loss: 1.5938 | Val RMSE: 1.4274 | R2: 0.3721
# Seed 2 | Epoch 010 | Train Loss: 1.5095 | Val RMSE: 1.3687 | R2: 0.4227
# ✓ Saved best model for seed 2 (Val RMSE=1.3687)
# Seed 2 | Epoch 011 | Train Loss: 1.4770 | Val RMSE: 1.4154 | R2: 0.3826
# Seed 2 | Epoch 012 | Train Loss: 1.4321 | Val RMSE: 1.4366 | R2: 0.3640
# Seed 2 | Epoch 013 | Train Loss: 1.3854 | Val RMSE: 1.3973 | R2: 0.3983
# Seed 2 | Epoch 014 | Train Loss: 1.3268 | Val RMSE: 1.3207 | R2: 0.4625
# ✓ Saved best model for seed 2 (Val RMSE=1.3207)
# Seed 2 | Epoch 015 | Train Loss: 1.2716 | Val RMSE: 1.4108 | R2: 0.3867
# Seed 2 | Epoch 016 | Train Loss: 1.2511 | Val RMSE: 1.3687 | R2: 0.4227
# Seed 2 | Epoch 017 | Train Loss: 1.2202 | Val RMSE: 1.3545 | R2: 0.4346
# Seed 2 | Epoch 018 | Train Loss: 1.1492 | Val RMSE: 1.3790 | R2: 0.4140
# Seed 2 | Epoch 019 | Train Loss: 1.1336 | Val RMSE: 1.3650 | R2: 0.4259
# Seed 2 | Epoch 020 | Train Loss: 1.1069 | Val RMSE: 1.3518 | R2: 0.4369
# Seed 2 | Epoch 021 | Train Loss: 1.0776 | Val RMSE: 1.3590 | R2: 0.4309
# Seed 2 | Epoch 022 | Train Loss: 1.0271 | Val RMSE: 1.3798 | R2: 0.4133
# Seed 2 | Epoch 023 | Train Loss: 1.0175 | Val RMSE: 1.3226 | R2: 0.4609
# Seed 2 | Epoch 024 | Train Loss: 0.9786 | Val RMSE: 1.4896 | R2: 0.3162
# Seed 2 | Epoch 025 | Train Loss: 0.9681 | Val RMSE: 1.3682 | R2: 0.4231
# Seed 2 | Epoch 026 | Train Loss: 0.9191 | Val RMSE: 1.3381 | R2: 0.4482
# Seed 2 | Epoch 027 | Train Loss: 0.8978 | Val RMSE: 1.3565 | R2: 0.4330
# Seed 2 | Epoch 028 | Train Loss: 0.8974 | Val RMSE: 1.3539 | R2: 0.4351
# Seed 2 | Epoch 029 | Train Loss: 0.8585 | Val RMSE: 1.3279 | R2: 0.4566
# Seed 2 | Epoch 030 | Train Loss: 0.8521 | Val RMSE: 1.4164 | R2: 0.3817
# Seed 2 | Epoch 031 | Train Loss: 0.8222 | Val RMSE: 1.3345 | R2: 0.4512
# Seed 2 | Epoch 032 | Train Loss: 0.8116 | Val RMSE: 1.3437 | R2: 0.4436
# Seed 2 | Epoch 033 | Train Loss: 0.7951 | Val RMSE: 1.4016 | R2: 0.3946
# Seed 2 | Epoch 034 | Train Loss: 0.7756 | Val RMSE: 1.3220 | R2: 0.4614
# Seed 2 | Epoch 035 | Train Loss: 0.7618 | Val RMSE: 1.3411 | R2: 0.4458
# Seed 2 | Epoch 036 | Train Loss: 0.7311 | Val RMSE: 1.3368 | R2: 0.4493
# Seed 2 | Epoch 037 | Train Loss: 0.7180 | Val RMSE: 1.3452 | R2: 0.4424
# Seed 2 | Epoch 038 | Train Loss: 0.7062 | Val RMSE: 1.3590 | R2: 0.4309
# Seed 2 | Epoch 039 | Train Loss: 0.6948 | Val RMSE: 1.3488 | R2: 0.4394
# Seed 2 | Epoch 040 | Train Loss: 0.6753 | Val RMSE: 1.3721 | R2: 0.4198
# Seed 2 | Epoch 041 | Train Loss: 0.6734 | Val RMSE: 1.3821 | R2: 0.4113
# Seed 2 | Epoch 042 | Train Loss: 0.6773 | Val RMSE: 1.3360 | R2: 0.4500
# Seed 2 | Epoch 043 | Train Loss: 0.6599 | Val RMSE: 1.3239 | R2: 0.4598
# Seed 2 | Epoch 044 | Train Loss: 0.6300 | Val RMSE: 1.3508 | R2: 0.4377
# Seed 2 | Epoch 045 | Train Loss: 0.6222 | Val RMSE: 1.3142 | R2: 0.4678
# ✓ Saved best model for seed 2 (Val RMSE=1.3142)
# Seed 2 | Epoch 046 | Train Loss: 0.6205 | Val RMSE: 1.3288 | R2: 0.4559
# Seed 2 | Epoch 047 | Train Loss: 0.6004 | Val RMSE: 1.3197 | R2: 0.4633
# Seed 2 | Epoch 048 | Train Loss: 0.5956 | Val RMSE: 1.3445 | R2: 0.4430
# Seed 2 | Epoch 049 | Train Loss: 0.6058 | Val RMSE: 1.3557 | R2: 0.4336
# Seed 2 | Epoch 050 | Train Loss: 0.5935 | Val RMSE: 1.3935 | R2: 0.4016
# Seed 2 TEST: RMSE=1.2844, R2=0.4688, Unc-Err Corr=0.0473, ECE=0.9793
# Seed 3 | Epoch 001 | Train Loss: 4.1154 | Val RMSE: 1.6364 | R2: 0.1748
# ✓ Saved best model for seed 3 (Val RMSE=1.6364)
# Seed 3 | Epoch 002 | Train Loss: 2.2495 | Val RMSE: 1.4875 | R2: 0.3182
# ✓ Saved best model for seed 3 (Val RMSE=1.4875)
# Seed 3 | Epoch 003 | Train Loss: 2.0885 | Val RMSE: 1.6375 | R2: 0.1737
# Seed 3 | Epoch 004 | Train Loss: 1.9477 | Val RMSE: 1.4957 | R2: 0.3106
# Seed 3 | Epoch 005 | Train Loss: 1.8843 | Val RMSE: 1.4189 | R2: 0.3795
# ✓ Saved best model for seed 3 (Val RMSE=1.4189)
# Seed 3 | Epoch 006 | Train Loss: 1.7675 | Val RMSE: 1.4095 | R2: 0.3877
# ✓ Saved best model for seed 3 (Val RMSE=1.4095)
# Seed 3 | Epoch 007 | Train Loss: 1.6722 | Val RMSE: 1.3900 | R2: 0.4046
# ✓ Saved best model for seed 3 (Val RMSE=1.3900)
# Seed 3 | Epoch 008 | Train Loss: 1.6151 | Val RMSE: 1.5227 | R2: 0.2855
# Seed 3 | Epoch 009 | Train Loss: 1.5527 | Val RMSE: 1.4062 | R2: 0.3907
# Seed 3 | Epoch 010 | Train Loss: 1.5000 | Val RMSE: 1.4287 | R2: 0.3710
# Seed 3 | Epoch 011 | Train Loss: 1.4170 | Val RMSE: 1.4943 | R2: 0.3119
# Seed 3 | Epoch 012 | Train Loss: 1.3791 | Val RMSE: 1.3440 | R2: 0.4434
# ✓ Saved best model for seed 3 (Val RMSE=1.3440)
# Seed 3 | Epoch 013 | Train Loss: 1.3254 | Val RMSE: 1.3484 | R2: 0.4397
# Seed 3 | Epoch 014 | Train Loss: 1.2778 | Val RMSE: 1.4041 | R2: 0.3924
# Seed 3 | Epoch 015 | Train Loss: 1.2402 | Val RMSE: 1.3245 | R2: 0.4594
# ✓ Saved best model for seed 3 (Val RMSE=1.3245)
# Seed 3 | Epoch 016 | Train Loss: 1.1877 | Val RMSE: 1.3403 | R2: 0.4464
# Seed 3 | Epoch 017 | Train Loss: 1.1779 | Val RMSE: 1.3563 | R2: 0.4332
# Seed 3 | Epoch 018 | Train Loss: 1.1397 | Val RMSE: 1.3630 | R2: 0.4275
# Seed 3 | Epoch 019 | Train Loss: 1.0941 | Val RMSE: 1.3556 | R2: 0.4337
# Seed 3 | Epoch 020 | Train Loss: 1.0721 | Val RMSE: 1.3255 | R2: 0.4586
# Seed 3 | Epoch 021 | Train Loss: 1.0353 | Val RMSE: 1.3273 | R2: 0.4571
# Seed 3 | Epoch 022 | Train Loss: 1.0016 | Val RMSE: 1.3434 | R2: 0.4438
# Seed 3 | Epoch 023 | Train Loss: 0.9927 | Val RMSE: 1.4229 | R2: 0.3761
# Seed 3 | Epoch 024 | Train Loss: 0.9506 | Val RMSE: 1.3453 | R2: 0.4423
# Seed 3 | Epoch 025 | Train Loss: 0.9298 | Val RMSE: 1.3810 | R2: 0.4123
# Seed 3 | Epoch 026 | Train Loss: 0.9133 | Val RMSE: 1.3106 | R2: 0.4707
# ✓ Saved best model for seed 3 (Val RMSE=1.3106)
# Seed 3 | Epoch 027 | Train Loss: 0.8924 | Val RMSE: 1.3447 | R2: 0.4427
# Seed 3 | Epoch 028 | Train Loss: 0.8460 | Val RMSE: 1.3247 | R2: 0.4592
# Seed 3 | Epoch 029 | Train Loss: 0.8410 | Val RMSE: 1.3263 | R2: 0.4579
# Seed 3 | Epoch 030 | Train Loss: 0.8108 | Val RMSE: 1.3548 | R2: 0.4343
# Seed 3 | Epoch 031 | Train Loss: 0.7826 | Val RMSE: 1.3466 | R2: 0.4412
# Seed 3 | Epoch 032 | Train Loss: 0.7772 | Val RMSE: 1.3562 | R2: 0.4332
# Seed 3 | Epoch 033 | Train Loss: 0.7710 | Val RMSE: 1.3374 | R2: 0.4488
# Seed 3 | Epoch 034 | Train Loss: 0.7396 | Val RMSE: 1.3329 | R2: 0.4525
# Seed 3 | Epoch 035 | Train Loss: 0.7402 | Val RMSE: 1.3143 | R2: 0.4676
# Seed 3 | Epoch 036 | Train Loss: 0.7211 | Val RMSE: 1.3311 | R2: 0.4540
# Seed 3 | Epoch 037 | Train Loss: 0.7046 | Val RMSE: 1.3614 | R2: 0.4288
# Seed 3 | Epoch 038 | Train Loss: 0.6881 | Val RMSE: 1.3256 | R2: 0.4585
# Seed 3 | Epoch 039 | Train Loss: 0.6852 | Val RMSE: 1.3078 | R2: 0.4729
# ✓ Saved best model for seed 3 (Val RMSE=1.3078)
# Seed 3 | Epoch 040 | Train Loss: 0.6442 | Val RMSE: 1.3092 | R2: 0.4718
# Seed 3 | Epoch 041 | Train Loss: 0.6539 | Val RMSE: 1.3539 | R2: 0.4351
# Seed 3 | Epoch 042 | Train Loss: 0.6598 | Val RMSE: 1.3209 | R2: 0.4623
# Seed 3 | Epoch 043 | Train Loss: 0.6405 | Val RMSE: 1.3234 | R2: 0.4603
# Seed 3 | Epoch 044 | Train Loss: 0.6305 | Val RMSE: 1.3675 | R2: 0.4237
# Seed 3 | Epoch 045 | Train Loss: 0.6091 | Val RMSE: 1.3313 | R2: 0.4538
# Seed 3 | Epoch 046 | Train Loss: 0.5871 | Val RMSE: 1.3071 | R2: 0.4735
# ✓ Saved best model for seed 3 (Val RMSE=1.3071)
# Seed 3 | Epoch 047 | Train Loss: 0.6004 | Val RMSE: 1.3587 | R2: 0.4311
# Seed 3 | Epoch 048 | Train Loss: 0.5769 | Val RMSE: 1.3445 | R2: 0.4430
# Seed 3 | Epoch 049 | Train Loss: 0.5714 | Val RMSE: 1.3407 | R2: 0.4460
# Seed 3 | Epoch 050 | Train Loss: 0.5596 | Val RMSE: 1.3271 | R2: 0.4573
# Seed 3 TEST: RMSE=1.2601, R2=0.4887, Unc-Err Corr=0.0466, ECE=0.9678
# Seed 4 | Epoch 001 | Train Loss: 4.1701 | Val RMSE: 1.6293 | R2: 0.1820
# ✓ Saved best model for seed 4 (Val RMSE=1.6293)
# Seed 4 | Epoch 002 | Train Loss: 2.2319 | Val RMSE: 1.5210 | R2: 0.2870
# ✓ Saved best model for seed 4 (Val RMSE=1.5210)
# Seed 4 | Epoch 003 | Train Loss: 2.0773 | Val RMSE: 1.4752 | R2: 0.3293
# ✓ Saved best model for seed 4 (Val RMSE=1.4752)
# Seed 4 | Epoch 004 | Train Loss: 1.9814 | Val RMSE: 1.5426 | R2: 0.2667
# Seed 4 | Epoch 005 | Train Loss: 1.8892 | Val RMSE: 1.4968 | R2: 0.3096
# Seed 4 | Epoch 006 | Train Loss: 1.8079 | Val RMSE: 1.4544 | R2: 0.3481
# ✓ Saved best model for seed 4 (Val RMSE=1.4544)
# Seed 4 | Epoch 007 | Train Loss: 1.7253 | Val RMSE: 1.5789 | R2: 0.2318
# Seed 4 | Epoch 008 | Train Loss: 1.6457 | Val RMSE: 1.3699 | R2: 0.4217
# ✓ Saved best model for seed 4 (Val RMSE=1.3699)
# Seed 4 | Epoch 009 | Train Loss: 1.5754 | Val RMSE: 1.4123 | R2: 0.3853
# Seed 4 | Epoch 010 | Train Loss: 1.5275 | Val RMSE: 1.3841 | R2: 0.4096
# Seed 4 | Epoch 011 | Train Loss: 1.4760 | Val RMSE: 1.3888 | R2: 0.4056
# Seed 4 | Epoch 012 | Train Loss: 1.4005 | Val RMSE: 1.3605 | R2: 0.4296
# ✓ Saved best model for seed 4 (Val RMSE=1.3605)
# Seed 4 | Epoch 013 | Train Loss: 1.3649 | Val RMSE: 1.4103 | R2: 0.3871
# Seed 4 | Epoch 014 | Train Loss: 1.3247 | Val RMSE: 1.3693 | R2: 0.4222
# Seed 4 | Epoch 015 | Train Loss: 1.3008 | Val RMSE: 1.3739 | R2: 0.4183
# Seed 4 | Epoch 016 | Train Loss: 1.2496 | Val RMSE: 1.3470 | R2: 0.4408
# ✓ Saved best model for seed 4 (Val RMSE=1.3470)
# Seed 4 | Epoch 017 | Train Loss: 1.1941 | Val RMSE: 1.4842 | R2: 0.3212
# Seed 4 | Epoch 018 | Train Loss: 1.1776 | Val RMSE: 1.3651 | R2: 0.4257
# Seed 4 | Epoch 019 | Train Loss: 1.1171 | Val RMSE: 1.3597 | R2: 0.4303
# Seed 4 | Epoch 020 | Train Loss: 1.1016 | Val RMSE: 1.3623 | R2: 0.4281
# Seed 4 | Epoch 021 | Train Loss: 1.0779 | Val RMSE: 1.4237 | R2: 0.3754
# Seed 4 | Epoch 022 | Train Loss: 1.0461 | Val RMSE: 1.3606 | R2: 0.4295
# Seed 4 | Epoch 023 | Train Loss: 0.9970 | Val RMSE: 1.3468 | R2: 0.4410
# ✓ Saved best model for seed 4 (Val RMSE=1.3468)
# Seed 4 | Epoch 024 | Train Loss: 0.9989 | Val RMSE: 1.3361 | R2: 0.4498
# ✓ Saved best model for seed 4 (Val RMSE=1.3361)
# Seed 4 | Epoch 025 | Train Loss: 0.9642 | Val RMSE: 1.4091 | R2: 0.3881
# Seed 4 | Epoch 026 | Train Loss: 0.9409 | Val RMSE: 1.3663 | R2: 0.4247
# Seed 4 | Epoch 027 | Train Loss: 0.9005 | Val RMSE: 1.3713 | R2: 0.4205
# Seed 4 | Epoch 028 | Train Loss: 0.8849 | Val RMSE: 1.3746 | R2: 0.4177
# Seed 4 | Epoch 029 | Train Loss: 0.8553 | Val RMSE: 1.3437 | R2: 0.4436
# Seed 4 | Epoch 030 | Train Loss: 0.8581 | Val RMSE: 1.3387 | R2: 0.4477
# Seed 4 | Epoch 031 | Train Loss: 0.8410 | Val RMSE: 1.3251 | R2: 0.4589
# ✓ Saved best model for seed 4 (Val RMSE=1.3251)
# Seed 4 | Epoch 032 | Train Loss: 0.8117 | Val RMSE: 1.3302 | R2: 0.4547
# Seed 4 | Epoch 033 | Train Loss: 0.8018 | Val RMSE: 1.3207 | R2: 0.4625
# ✓ Saved best model for seed 4 (Val RMSE=1.3207)
# Seed 4 | Epoch 034 | Train Loss: 0.7704 | Val RMSE: 1.3210 | R2: 0.4623
# Seed 4 | Epoch 035 | Train Loss: 0.7661 | Val RMSE: 1.3274 | R2: 0.4570
# Seed 4 | Epoch 036 | Train Loss: 0.7425 | Val RMSE: 1.3208 | R2: 0.4624
# Seed 4 | Epoch 037 | Train Loss: 0.7380 | Val RMSE: 1.3723 | R2: 0.4196
# Seed 4 | Epoch 038 | Train Loss: 0.7035 | Val RMSE: 1.3655 | R2: 0.4254
# Seed 4 | Epoch 039 | Train Loss: 0.7019 | Val RMSE: 1.3230 | R2: 0.4606
# Seed 4 | Epoch 040 | Train Loss: 0.6724 | Val RMSE: 1.3299 | R2: 0.4550
# Seed 4 | Epoch 041 | Train Loss: 0.6731 | Val RMSE: 1.3327 | R2: 0.4526
# Seed 4 | Epoch 042 | Train Loss: 0.6644 | Val RMSE: 1.3207 | R2: 0.4625
# Seed 4 | Epoch 043 | Train Loss: 0.6638 | Val RMSE: 1.3319 | R2: 0.4533
# Seed 4 | Epoch 044 | Train Loss: 0.6431 | Val RMSE: 1.3705 | R2: 0.4211
# Seed 4 | Epoch 045 | Train Loss: 0.6352 | Val RMSE: 1.3264 | R2: 0.4578
# Seed 4 | Epoch 046 | Train Loss: 0.6063 | Val RMSE: 1.3514 | R2: 0.4372
# Seed 4 | Epoch 047 | Train Loss: 0.5975 | Val RMSE: 1.3712 | R2: 0.4206
# Seed 4 | Epoch 048 | Train Loss: 0.6121 | Val RMSE: 1.3267 | R2: 0.4576
# Seed 4 | Epoch 049 | Train Loss: 0.5828 | Val RMSE: 1.3753 | R2: 0.4171
# Seed 4 | Epoch 050 | Train Loss: 0.6046 | Val RMSE: 1.3440 | R2: 0.4434
# Seed 4 TEST: RMSE=1.2779, R2=0.4742, Unc-Err Corr=0.0279, ECE=0.9818
#
# AGGREGATE RESULTS (5 seeds):
# RMSE mean: 1.2749, range: 1.2601-1.2844
# R2 mean: 0.4766, range: 0.4688-0.4887
# Unc-Err Corr mean: 0.0331
# ECE mean: 0.9764
